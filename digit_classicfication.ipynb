# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
plt.imshow(x_train[0], cmap="gray") # Import the image
plt.show() # Plot the image

# %%
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit(x=x_train, y=y_train, epochs=25)
# Out:
# Epoch 1/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0505 - accuracy: 0.9850
# Epoch 2/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0452 - accuracy: 0.9862
# Epoch 3/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0365 - accuracy: 0.9887
# Epoch 4/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0309 - accuracy: 0.9896
# Epoch 5/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0285 - accuracy: 0.9908
# Epoch 6/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0259 - accuracy: 0.9922
# Epoch 7/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0226 - accuracy: 0.9927
# Epoch 8/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0223 - accuracy: 0.9933
# Epoch 9/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0182 - accuracy: 0.9943
# Epoch 10/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0176 - accuracy: 0.9940
# Epoch 11/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0166 - accuracy: 0.9941
# Epoch 12/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0140 - accuracy: 0.9953
# Epoch 13/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0165 - accuracy: 0.9945
# Epoch 14/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0145 - accuracy: 0.9952
# Epoch 15/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0128 - accuracy: 0.9957
# Epoch 16/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0127 - accuracy: 0.9959
# Epoch 17/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0118 - accuracy: 0.9961
# Epoch 18/25
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0114 - accuracy: 0.9963
# Epoch 19/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0102 - accuracy: 0.9966
# Epoch 20/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0101 - accuracy: 0.9967
# Epoch 21/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0105 - accuracy: 0.9966
# Epoch 22/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0100 - accuracy: 0.9969
# Epoch 23/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0119 - accuracy: 0.9962
# Epoch 24/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0101 - accuracy: 0.9967
# Epoch 25/25
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0094 - accuracy: 0.9969

# %%
predictions = model.predict([x_test])
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
for i in range(10):
    print("Original Number: ",y_test[i])
    print("Predicted Number: ",np.argmax(predictions[i]))
    print("Image")
    plt.imshow(x_test[i], cmap="gray")
    plt.show()
    print("-------------------------------------------")
# Out:
# Original Number:  7
# Predicted Number:  7
# Image
# -------------------------------------------
# Original Number:  2
# Predicted Number:  2
# Image
# -------------------------------------------
# Original Number:  1
# Predicted Number:  1
# Image
# -------------------------------------------
# Original Number:  0
# Predicted Number:  0
# Image
# -------------------------------------------
# Original Number:  4
# Predicted Number:  4
# Image
# -------------------------------------------
# Original Number:  1
# Predicted Number:  1
# Image
# -------------------------------------------
# Original Number:  4
# Predicted Number:  4
# Image
# -------------------------------------------
# Original Number:  9
# Predicted Number:  9
# Image
# -------------------------------------------
# Original Number:  5
# Predicted Number:  5
# Image
# -------------------------------------------
# Original Number:  9
# Predicted Number:  9
# Image
# -------------------------------------------
